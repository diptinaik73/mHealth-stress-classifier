# %% [markdown]
# # MHEALTH Multimodal Sensor Analysis
#
# This notebook demonstrates basic analysis and classification of combined ECG and IMU data from the MHEALTH dataset.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix

# %% [markdown]
# ### Load Your MHEALTH Dataset
# _(Replace the path below with the correct one on your machine)_

# %%
# Example loading (replace with your actual file)
# data = pd.read_csv('mhealth_combined_ecg_imu.csv')
